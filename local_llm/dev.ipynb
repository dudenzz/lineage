# %% [markdown]
# Verify CUDA, graphic card endpoint and libraries

# %%
import torch
import bitsandbytes as bnb

print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU Name: {torch.cuda.get_device_name(0)}")
# Check if bitsandbytes can find the GPU
print(f"Bitsandbytes GPU support: {bnb.cuda_setup.main.get_compute_capabilities(torch.cuda.current_device())}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 import bitsandbytes as bnb
#       4 print(f"PyTorch Version: {torch.__version__}")
#
# ModuleNotFoundError: No module named 'torch'
